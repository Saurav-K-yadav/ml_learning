# %% [markdown]
# <a href="https://colab.research.google.com/github/Saurav-K-yadav/ml_learning/blob/main/univariate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import kagglehub
from google.colab import userdata
import os

os.environ['KAGGLE_USERNAME'] = userdata.get('KAGGLE_USERNAME')
os.environ['KAGGLE_KEY'] = userdata.get('KAGGLE_TOKEN')

path = kagglehub.dataset_download("yasserh/titanic-dataset")

print("Path to dataset files:", path)

# %%
df=pd.read_csv('/kaggle/input/titanic-dataset/Titanic-Dataset.csv')

# %%
df.info()

# %%
df.describe()

# %%
df.sample(10)

# %%
import seaborn as sns

# %%
df['Survived'].value_counts()

# %%
sns.countplot(data=df,x='Survived')

# %%
df['Pclass'].value_counts()

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(df['Sex'],df['Survived'])

# %%
ax=sns.countplot(x=df['Pclass'],hue=df['Pclass'])
for contain in ax.containers:
  ax.bar_label(contain)
plt.show()

# %%
ax = sns.barplot(data=df, x='Sex', y='Survived', hue='Sex', legend=False,estimator=sum,errorbar=None)
for container in ax.containers:
    ax.bar_label(container)

# %%
df['Sex'].value_counts().plot(kind="pie",autopct='%.2f',labels=['Men','Women'])

# %%
plt.hist(df['Age'],bins=10)

# %%
sns.distplot(df['Age'])

# %%
sns.boxplot(df['Age'])

# %%
sns.boxplot(df['Fare'])

# %% [markdown]
# Seaborn

# %%
import seaborn as sns

# %%
tips=sns.load_dataset('tips')

# %%
tips.sample(10)

# %%
flights=sns.load_dataset('flights')

# %%
flights.sample(10)

# %%
iris=sns.load_dataset('iris')

# %%
iris.sample(10)

# %% [markdown]
# For numerical vs numerical, scatterplot

# %%
sns.scatterplot(data=tips,x=tips['total_bill'],y=tips['tip'],hue=tips['sex'],style=tips['smoker'],size=tips['size'])

# %% [markdown]
# Bar plot
#
# numerical vs categorical

# %%
sns.barplot(data=df,x=df['Pclass'],y=df['Age'],hue=df['Sex'])

# %%
sns.boxplot(data=df,x=df['Sex'],y=df['Age'],hue=df['Survived'])

# %% [markdown]
# distplot

# %%
sns.displot(data=df, x='Age', hue='Survived', kind='kde', fill=True)

# %% [markdown]
# heatmap

# %%
pd.crosstab(df['Pclass'],df['Survived'])

# %%
sns.heatmap(pd.crosstab(df['Pclass'],df['Survived']))

# %%
x=pd.DataFrame(df.groupby('Pclass')['Survived'].mean())
x

# %%
sns.heatmap(x)

# %% [markdown]
# clustermap

# %%
sns.clustermap(pd.crosstab(df['SibSp'],df['Survived']))

# %% [markdown]
# PairPlot

# %%
sns.pairplot(iris,hue='species')

# %% [markdown]
# lineplot-->timebased

# %%
flights.head()

# %%
sns.lineplot(flights.groupby('year').sum(numeric_only=True))

# %%
flights.pivot_table(values='passengers',index='month',columns='year')

# %%
sns.heatmap(flights.pivot_table(values='passengers',index='month',columns='year'))

# %%
sns.clustermap(flights.pivot_table(values='passengers',index='month',columns='year'))

# %% [markdown]
# **Automating**

# %% [markdown]
# Pandas *Profiler*

# %%
df.sample(10)

# %%
# !pip install ydata-profiling

# %%
from ydata_profiling import ProfileReport

# %%
prof=ProfileReport(df)

# %%
prof
